# %% [markdown]
# # Week 3 — Sentiment Analysis
#
# Runs the existing Week 3 sentiment pipeline.
# Expected output: `data/processed/player_sentiment_features.csv`

# %%
import sys
# !{sys.executable} scripts/week3_sentiment_pipeline.py

# %%
import pandas as pd
from pathlib import Path
p = Path('data/processed/player_sentiment_features.csv')
df = pd.read_csv(p)
df.head()
