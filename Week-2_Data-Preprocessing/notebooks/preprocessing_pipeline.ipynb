# %% [markdown]
# # Week 2 — Preprocessing Pipeline
# This notebook is a lightweight runbook that calls the existing preprocessing script.
#
# Outputs are written to `data/processed/` (large artifacts are ignored by git).

# %%
import sys
# !{sys.executable} scripts/week2_data_processing.py
