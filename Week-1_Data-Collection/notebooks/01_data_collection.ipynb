# %% [markdown]
# # Week 1 — Data Collection
#
# This notebook runs the Week 1 data collection scripts from the repo root.
# It downloads/creates raw + processed datasets under `data/raw/` and `data/processed/`.

# %%
import sys

# 1) StatsBomb Open Data
# !{sys.executable} scripts/week1_download_statsbomb.py --competition-id 43 --season-id 106 --max-matches 50
# !{sys.executable} scripts/week1_build_player_performance.py

# %%
import sys

# 2) Transfermarkt (requires players list in data/external/players.csv)
# !{sys.executable} scripts/week1_transfermarkt_scrape.py --input data/external/players.csv

# %%
import sys

# 3) Twitter sentiment (requires TWITTER_BEARER_TOKEN in .env or passed via args)
# !{sys.executable} scripts/week1_twitter_sentiment.py --input data/external/players.csv
