# %% [markdown]
# # Week 1 — Initial EDA
#
# Runs the existing EDA script to generate the exploration report and figures.
# - Report: `reports/week1_exploration_report.md`
# - Figures: `reports/figures/*.png`

# %%
import sys
# !{sys.executable} scripts/week1_eda.py

# %%
from pathlib import Path
figs = sorted(Path('reports/figures').glob('*.png'))
len(figs), [p.name for p in figs[:10]]
